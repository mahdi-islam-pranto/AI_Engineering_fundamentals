# %%
# import all modules
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# import dataset
# df = pd.read_csv('/content/drive/MyDrive/datasets/StressLevelDataset.csv')
# df.head()

# %%
# import dataset
df = pd.read_csv('/content/drive/MyDrive/datasets/coaster_db.csv')
df.head(10)
# Out:
#                              coaster_name            Length             Speed  \
# 0                      Switchback Railway    600 ft (180 m)  6 mph (9.7 km/h)
# 1                       Flip Flap Railway               NaN               NaN
# 2  Switchback Railway (Euclid Beach Park)               NaN               NaN
# 3            Loop the Loop (Coney Island)               NaN               NaN
# 4            Loop the Loop (Young's Pier)               NaN               NaN
# 5                          Cannon Coaster               NaN               NaN
# 6                           Leap-The-Dips  1,452 ft (443 m)  10 mph (16 km/h)
# 7        Figure Eight (Euclid Beach Park)               NaN               NaN
# 8                            Drop the Dip               NaN               NaN
# 9      Scenic Railway (Euclid Beach Park)               NaN               NaN
#
#                          Location     Status   Opening date  \
# ...

# %%
df.shape
# Out:
# (1087, 56)

# %%
# see all colums and their d-type
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1087 entries, 0 to 1086
# Data columns (total 56 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   coaster_name                   1087 non-null   object
#  1   Length                         953 non-null    object
#  2   Speed                          937 non-null    object
#  3   Location                       1087 non-null   object
#  4   Status                         874 non-null    object
#  5   Opening date                   837 non-null    object
#  6   Type                           1087 non-null   object
#  7   Manufacturer                   1028 non-null   object
#  8   Height restriction             831 non-null    object
#  9   Model                          744 non-null    object
#  10  Height                         965 non-null    object
#  11  Inversions                     932 non-null    float64
# ...

# %%
df.dtypes
# Out:
# coaster_name                      object
# Length                            object
# Speed                             object
# Location                          object
# Status                            object
# Opening date                      object
# Type                              object
# Manufacturer                      object
# Height restriction                object
# Model                             object
# Height                            object
# Inversions                       float64
# Lift/launch system                object
# Cost                              object
# Trains                            object
# Park section                      object
# Duration                          object
# Capacity                          object
# G-force                           object
# Designer                          object
# Max vertical angle                object
# Drop                              object
# Soft opening date                 object
# ...

# %%
df.describe()
# Out:
#        Inversions  year_introduced    latitude   longitude  speed1_value  \
# count  932.000000      1087.000000  812.000000  812.000000    937.000000
# mean     1.547210      1994.986201   38.373484  -41.595373     53.850374
# std      2.114073        23.475248   15.516596   72.285227     23.385518
# min      0.000000      1884.000000  -48.261700 -123.035700      5.000000
# 25%      0.000000      1989.000000   35.031050  -84.552200     40.000000
# 50%      0.000000      2000.000000   40.289800  -76.653600     50.000000
# 75%      3.000000      2010.000000   44.799600    2.778100     63.000000
# max     14.000000      2022.000000   63.230900  153.426500    240.000000
#
#         speed_mph  height_value   height_ft  Inversions_clean  Gforce_clean
# count  937.000000    965.000000  171.000000       1087.000000    362.000000
# mean    48.617289     89.575171  101.996491          1.326587      3.824006
# std     16.678031    136.246444   67.329092          2.030854      0.989998
# ...

# %% [markdown]
# ## Data Preparation

# %%
df.columns
# Out:
# Index(['coaster_name', 'Length', 'Speed', 'Location', 'Status', 'Opening date',
#        'Type', 'Manufacturer', 'Height restriction', 'Model', 'Height',
#        'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
#        'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
#        'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
#        'Track layout', 'Fastrack available', 'Soft opening date.1',
#        'Closing date', 'Opened', 'Replaced by', 'Website',
#        'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
#        'Single rider line available', 'Restraint Style',
#        'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
#        'year_introduced', 'latitude', 'longitude', 'Type_Main',
#        'opening_date_clean', 'speed1', 'speed2', 'speed1_value', 'speed1_unit',
#        'speed_mph', 'height_value', 'height_unit', 'height_ft',
#        'Inversions_clean', 'Gforce_clean'],
# ...

# %%
# drop columns that are not useful (single or multiple)
# df = df.drop(columns=["Speed" , "Location", "Opening date"], axis=1 )
# df.columns

# %%
# drop by index and make a copy dataset (for too many column dropping)
df = df[['coaster_name', 'Length', 'Speed', 'Location', 'Status', 'Opening date',
       'Type', 'Manufacturer', 'Height restriction', 'Model', 'Height',
       'Inversions',
         #'Lift/launch system', 'Cost', 'Trains', 'Park section',
       'Duration',
         'Capacity',
         #'G-force', 'Designer', 'Max vertical angle',
       'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
       #'Track layout', 'Fastrack available', 'Soft opening date.1',
       'Closing date', 'Opened',
         #'Replaced by', 'Website',
       'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
       #'Single rider line available', 'Restraint Style',
       'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
       #'year_introduced', 'latitude', 'longitude', 'Type_Main',
       'opening_date_clean', 'speed1', 'speed2', 'speed1_value', 'speed1_unit',
       'speed_mph', 'height_value', 'height_unit', 'height_ft',
       'Inversions_clean', 'Gforce_clean']].copy()

# %%
df.shape
# Out:
# (1087, 38)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1087 entries, 0 to 1086
# Data columns (total 38 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   coaster_name                   1087 non-null   object
#  1   Length                         953 non-null    object
#  2   Speed                          937 non-null    object
#  3   Location                       1087 non-null   object
#  4   Status                         874 non-null    object
#  5   Opening date                   837 non-null    object
#  6   Type                           1087 non-null   object
#  7   Manufacturer                   1028 non-null   object
#  8   Height restriction             831 non-null    object
#  9   Model                          744 non-null    object
#  10  Height                         965 non-null    object
#  11  Inversions                     932 non-null    float64
# ...

# %%
# change the d-type of a collumn
df["opening_date_clean"] = pd.to_datetime(df["opening_date_clean"])
df['opening_date_clean']
# Out:
# 0      1884-06-16
# 1      1895-01-01
# 2             NaT
# 3      1901-01-01
# 4      1901-01-01
#           ...
# 1082          NaT
# 1083   2022-01-01
# 1084   2016-06-16
# 1085          NaT
# 1086   2022-01-01
# Name: opening_date_clean, Length: 1087, dtype: datetime64[ns]

# %%
# Rename Columns
df = df.rename(columns={
    "coaster_name": "Coaster_Name",
    "Opening date": "Opening_Date",
    "Height restriction": "Height_Restriction",
    "Max vertical angle": "Max_Vertical_Angle",
    "Closing date": "Closing_Date",
    "Flash Pass Available": "Flash_Pass_Available",
    "Must transfer from wheelchair": "Must_Transfer_From_Wheelchair",
    "Fastrack available": "Fastrack_Available",
    "Soft opening date": "Soft_Opening_Date",
    "Flash Pass available": "Flash_Pass_Available",

})

# %%
# check how many missing values are there
df.isna().sum()
# Out:
# Coaster_Name                        0
# Length                            134
# Speed                             150
# Location                            0
# Status                            213
# Opening_Date                      250
# Type                                0
# Manufacturer                       59
# Height_Restriction                256
# Model                             343
# Height                            122
# Inversions                        155
# Duration                          322
# Capacity                          512
# Drop                              593
# Soft_Opening_Date                 991
# Fast Lane available              1018
# Replaced                          914
# Closing_Date                      851
# Opened                           1060
# Flash_Pass_Available             1037
# Must_Transfer_From_Wheelchair     981
# Theme                            1043
# Flash_Pass_Available             1041
# Acceleration                     1027
# ...

# %%
# check for duplicate rows within a column
df.duplicated(subset=['Coaster_Name', 'Opening_Date']).sum()
# Out:
# np.int64(97)

# %%
# keep only unique rows / non duplicates
df = df.loc[~df.duplicated(subset=['Coaster_Name', 'Opening_Date'])].reset_index(drop=True).copy()

# %%
# now check duplicates
df.duplicated(subset='Coaster_Name').sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (990, 38)

# %% [markdown]
# ## Feature Understanding
# ###   (univarite analysis)
#   - Bar plot
#   - Histogram
#   - KDE
#   - Boxplots

# %%
# understand speed_mph feature in rollar coaster
ax = df['speed_mph'].value_counts().head(10).plot(kind='bar' , title='Coaster Speed (mgh)')
ax.set_xlabel('Speed (mgh)')
ax.set_ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
# understand speed_mph feature with histogram plot
ax = df['speed_mph'].plot(kind='hist' , title='Coaster speed')
ax.set_xlabel('Speed (mgh)')
ax.set_ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
# # understand speed_mph feature with KDE plot
ax = df['speed_mph'].plot(kind='kde' , title='Coaster speed')
ax.set_xlabel('Speed (mgh)')
ax.set_ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# ## Feature Relationship

# %%
# first find all the numeric columns from df
numeric_cols = df.select_dtypes(include=np.number).columns.tolist()
numeric_cols
# Out:
# ['Inversions',
#  'speed1_value',
#  'speed_mph',
#  'height_value',
#  'height_ft',
#  'Inversions_clean',
#  'Gforce_clean']

# %%
# look at the relationship between speed_mph & height_ft
sns.scatterplot(data=df, x='speed_mph', y='height_ft')
plt.show()

# %%
# Take a look at the relationship between all features which is numeric
 # df co-relations
df_corr = df[['Inversions',
 'speed1_value',
 'speed_mph',
 'height_value',
 'height_ft',
 'Inversions_clean',
 'Gforce_clean']].corr()
df_corr
# Out:
#                   Inversions  speed1_value  speed_mph  height_value  \
# Inversions          1.000000      0.146756   0.230845      0.085210
# speed1_value        0.146756      1.000000   0.850365      0.079691
# speed_mph           0.230845      0.850365   1.000000      0.228372
# height_value        0.085210      0.079691   0.228372      1.000000
# height_ft           0.142907      0.808505   0.823216      1.000000
# Inversions_clean    1.000000      0.160813   0.246593      0.099028
# Gforce_clean        0.346522      0.398079   0.503828      0.344289
#
#                   height_ft  Inversions_clean  Gforce_clean
# Inversions         0.142907          1.000000      0.346522
# speed1_value       0.808505          0.160813      0.398079
# speed_mph          0.823216          0.246593      0.503828
# height_value       1.000000          0.099028      0.344289
# height_ft          1.000000          0.138286      0.480465
# Inversions_clean   0.138286          1.000000      0.339137
# ...

# %%
sns.heatmap(data=df_corr, annot=True)
# Out:
# <Axes: >
